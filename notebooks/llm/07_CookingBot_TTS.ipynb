# %% [markdown]
# # Testing of the Model with Text-To-Speech
#
# ---
#
# - Loads in the conversational models
# - Takes in queries from the user
# - outputs response with tts

# %%
# %pip install pandas numpy faiss-cpu sentence_transformers transformers torch peft==0.11.1 tqdm

# %%
# Load from Drive
